# %%
import pandas as pd 
import numpy as np 
import scipy.stats as st 
from scipy.interpolate import interp1d
from matplotlib import pyplot as plt 
import math
import statistics as stats

# %%
data=pd.read_csv('AR_1_U.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
w=data.iloc[:,1]
x=data.iloc[:,2]
z=data.iloc[:,3]
print(stats.stdev(x))
print(data)
# Out:
# 2.2148226206680794e+45
#            A         B             C             D
# 0   0.411784  1.138076  2.660000e+45  2.350000e+44
# 1   1.076529  2.549643  3.990000e+43  1.560000e+43
# 2   0.344893  1.805657  3.690000e+44  1.900000e+44
# 3   0.290591  1.104069  3.470000e+45  1.280000e+43
# 4   0.319685  1.767705  5.480000e+43  4.060000e+43
# ..       ...       ...           ...           ...
# 64  0.585102  2.337823  2.890000e+44  7.870000e+43
# 65  0.577945  1.263360  1.760000e+45  1.630000e+44
# 66  0.724814  2.294153  1.180000e+45  5.450000e+43
# 67  0.607669  2.162039  1.820000e+44  3.360000e+43
# 68  0.470268  2.291900  5.560000e+44  5.120000e+43
#
# [69 rows x 4 columns]

# %%
yerror = w
xerror = z
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('AR_U_1')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_AB")
plt.xscale('log')
#plt.yscale('log')
plt.grid()
plt.savefig("Luminosidad_UV_GALEX_AR_U_1_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('AR_1_G.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
x=data.iloc[:,1]
z=data.iloc[:,2]
print(stats.stdev(y)) # desviación estandar 
print(data)
# Out:
# 2.2403361665948585
#            A             C             D
# 0   1.455610  2.660000e+45  2.350000e+44
# 1   0.943962  3.990000e+43  1.560000e+43
# 2   0.443118  3.690000e+44  1.900000e+44
# 3   2.370353  3.470000e+45  1.280000e+43
# 4   0.432795  5.480000e+43  4.060000e+43
# ..       ...           ...           ...
# 75  1.127188  3.380000e+44  3.120000e+43
# 76  0.516945  9.040000e+44  3.340000e+43
# 77  0.616204  1.320000e+43  5.220000e+43
# 78  0.401092  2.890000e+44  8.750000e+43
# 79  0.401092  6.620000e+44  2.140000e+44
#
# [80 rows x 3 columns]

# %%
yerror = 2.2403361665948585
xerror = z
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('AR_G_1')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_AB")
plt.xscale('log')

plt.grid()
plt.savefig("Luminosidad_UV_GALEX_AR_G_1_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('AR_1_R.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
z=data.iloc[:,3]
w=data.iloc[:,1]
x=data.iloc[:,2]
print(stats.stdev(y)) # desviación estandar 
print(data)
# Out:
# 3.8745978368928253
#            A         B             C             D
# 0   0.915703  2.492778  2.660000e+45  2.350000e+44
# 1   1.132959  2.685760  3.990000e+43  1.560000e+43
# 2   0.379168  1.790669  3.690000e+44  1.900000e+44
# 3   0.415966  1.195463  3.470000e+45  1.280000e+43
# 4   0.449154  2.176936  5.480000e+43  4.060000e+43
# ..       ...       ...           ...           ...
# 79  1.486389  2.924665  6.620000e+44  2.140000e+44
# 80  0.685809  2.241289  4.590000e+44  4.640000e+43
# 81  0.825946  2.131792  2.730000e+44  3.280000e+43
# 82  0.890311  2.355310  1.010000e+45  5.650000e+43
# 83  1.053383  2.431714  2.200000e+45  8.130000e+43
#
# [84 rows x 4 columns]

# %%
yerror = w
xerror = z
plt.plot(x,y,'ro')

plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('AR_R_1')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_AB")
plt.xscale('log')

plt.grid()
plt.savefig("Luminosidad_UV_GALEX_AR_R_1_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('AR_1_I.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
z=data.iloc[:,3]
x=data.iloc[:,2]
print(stats.stdev(y)) # desviación estandar 
print(data)
# Out:
# 3.398283469246419
#            A         B             C             D
# 0   1.471469  2.101748  2.660000e+45  2.350000e+44
# 1   1.020110  2.439465  3.990000e+43  1.560000e+43
# 2   0.537924  1.960089  3.690000e+44  1.900000e+44
# 3   0.343263  1.072385  3.470000e+45  1.280000e+43
# 4   0.115155  1.468025  5.480000e+43  4.060000e+43
# ..       ...       ...           ...           ...
# 79  0.629876  2.066870  6.620000e+44  2.140000e+44
# 80  0.668968  2.263383  4.590000e+44  4.640000e+43
# 81  2.652720  1.913659  2.730000e+44  3.280000e+43
# 82  1.245417  2.582207  1.010000e+45  5.650000e+43
# 83  0.927963  1.699707  2.200000e+45  8.130000e+43
#
# [84 rows x 4 columns]

# %%
yerror = 3.398283469246419
xerror = z
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('AR_I_1')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_AB")
plt.xscale('log')

plt.grid()
plt.savefig("Luminosidad_UV_GALEX_AR_I_1_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('AR_1_Z.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
z=data.iloc[:,3]
x=data.iloc[:,2]
print(stats.stdev(y)) # desviación estandar 
print(data)
# Out:
# 0.6684042867392109
#            A         B             C             D
# 0   0.534101  2.207213  2.660000e+45  2.350000e+44
# 1   0.544277  2.120358  3.990000e+43  1.560000e+43
# 2   0.497133  1.987317  3.690000e+44  1.900000e+44
# 3   0.416236  1.136550  3.470000e+45  1.280000e+43
# 4   0.731127  2.323023  5.480000e+43  4.060000e+43
# ..       ...       ...           ...           ...
# 75  0.598098  2.188719  3.380000e+44  3.120000e+43
# 76  0.468889  1.836836  9.040000e+44  3.340000e+43
# 77  0.782744  2.234345  1.320000e+43  5.220000e+43
# 78  0.500959  2.157437  2.890000e+44  8.750000e+43
# 79  0.722118  2.211141  6.620000e+44  2.140000e+44
#
# [80 rows x 4 columns]

# %%
yerror = 0.6684042867392109
xerror = z
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('AR_Z_1')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_AB")
plt.xscale('log')

plt.grid()
plt.savefig("Luminosidad_UV_GALEX_AR_Z_1_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
