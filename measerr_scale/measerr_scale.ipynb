# %%
import pandas as pd 
import numpy as np 
import scipy.stats as st 
from scipy.interpolate import interp1d
from matplotlib import pyplot as plt 
import math
import statistics as stats

# %%
data=pd.read_csv('measerr_scale_U.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
z=data.iloc[:,1]
x=data.iloc[:,2]
w=data.iloc[:,3]


print(stats.stdev(z)) # desviación estandar 
#print(stats.stdev(w)) # desviación estandar 
print(data)
# Out:
# 0.02489480093513288
#            A         B             C             D
# 0   1.195859  0.196453  2.660000e+45  2.350000e+44
# 1   1.170506  0.205177  3.990000e+43  1.560000e+43
# 2   1.032013  0.157972  3.690000e+44  1.900000e+44
# 3   0.917479  0.147812  3.470000e+45  1.280000e+43
# 4   0.877315  0.139783  5.480000e+43  4.060000e+43
# ..       ...       ...           ...           ...
# 65  1.032091  0.187493  1.760000e+45  1.630000e+44
# 66  1.160881  0.194522  1.180000e+45  5.450000e+43
# 67  0.993321  0.153457  1.820000e+44  3.360000e+43
# 68  1.043746  0.162104  5.560000e+44  5.120000e+43
# 69  1.082587  0.167039  9.080000e+44  5.850000e+43
#
# [70 rows x 4 columns]

# %%
yerror = z
xerror = w
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('measerr_scale_U')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX")
plt.xscale('log')
#plt.yscale('log')
#plt.ylim(0,)
#plt.xlim(10e44,11e45)
plt.grid()
plt.savefig("Luminosidad_UV_GALEX_measerr_scale_U_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('measerr_scale_G.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
z=data.iloc[:,1]
x=data.iloc[:,2]
w=data.iloc[:,3]


print(stats.stdev(z)) # desviación estandar 
#print(stats.stdev(w)) # desviación estandar 
print(data)
# Out:
# 0.03236277150394809
#            A         B             C             D
# 0   1.041636  0.220427  2.660000e+45  2.350000e+44
# 1   1.022801  0.219710  3.990000e+43  1.560000e+43
# 2   1.115778  0.188678  3.690000e+44  1.900000e+44
# 3   0.917479  0.147812  3.470000e+45  1.280000e+43
# 4   0.877315  0.139783  5.480000e+43  4.060000e+43
# ..       ...       ...           ...           ...
# 76  1.113626  0.253562  9.040000e+44  3.340000e+43
# 77  1.009048  0.184411  1.320000e+43  5.220000e+43
# 78  1.138252  0.176201  2.890000e+44  8.750000e+43
# 79  1.171940  0.198775  6.620000e+44  2.140000e+44
# 80  1.238977  0.197372  4.590000e+44  4.640000e+43
#
# [81 rows x 4 columns]

# %%
yerror = z
xerror = w
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('measerr_scale_G')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX")
plt.xscale('log')
#plt.yscale('log')
#plt.ylim(0,)
#plt.xlim(10e44,11e45)
plt.grid()
plt.savefig("Luminosidad_UV_GALEX_measerr_scale_G_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('measerr_scale_R.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
x=data.iloc[:,1]
w=data.iloc[:,2]



print(stats.stdev(y)) # desviación estandar 
#print(stats.stdev(w)) # desviación estandar 
print(data)
# Out:
# 0.1771718525435939
#            A             B             C
# 0   1.142239  2.660000e+45  2.350000e+44
# 1   1.052054  3.990000e+43  1.560000e+43
# 2   1.153307  3.690000e+44  1.900000e+44
# 3   1.214880  3.470000e+45  1.280000e+43
# 4   1.410062  5.480000e+43  4.060000e+43
# ..       ...           ...           ...
# 79  1.289388  6.620000e+44  2.140000e+44
# 80  1.084152  4.590000e+44  4.640000e+43
# 81  1.323335  2.730000e+44  3.280000e+43
# 82  1.124980  1.010000e+45  5.650000e+43
# 83  1.193282  2.200000e+45  8.130000e+43
#
# [84 rows x 3 columns]

# %%
yerror = 0.1771718525435939
xerror = w
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('measerr_scale_R')
plt.xlabel('erg/seg')
plt.title("Luminosidad_GALEX_5100")
plt.xscale('log')
#plt.yscale('log')
#plt.ylim(0,)
#plt.xlim(10e44,11e45)
plt.grid()
plt.savefig("Luminosidad_UV_GALEX_measerr_scale_R_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('measerr_scale_I.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
x=data.iloc[:,1]
w=data.iloc[:,2]



print(stats.stdev(y)) # desviación estandar 
#print(stats.stdev(w)) # desviación estandar 
print(data)
# Out:
# 0.15315518197491781
#            A             B    Unnamed: 2
# 0   1.133457  2.660000e+45  2.350000e+44
# 1   1.160523  3.990000e+43  1.560000e+43
# 2   1.067083  3.690000e+44  1.900000e+44
# 3   1.167257  3.470000e+45  1.280000e+43
# 4   1.147959  5.480000e+43  4.060000e+43
# ..       ...           ...           ...
# 79  1.509390  6.620000e+44  2.140000e+44
# 80  1.316358  4.590000e+44  4.640000e+43
# 81  1.288756  2.730000e+44  3.280000e+43
# 82  0.968654  1.010000e+45  5.650000e+43
# 83  1.077684  2.200000e+45  8.130000e+43
#
# [84 rows x 3 columns]

# %%
yerror = 0.15315518197491781
xerror = w
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('measerr_scale_I')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_5100")
plt.xscale('log')
#plt.yscale('log')
#plt.ylim(0,)
#plt.xlim(10e44,11e45)
plt.grid()
plt.savefig("Luminosidad_UV_GALEX_measerr_scale_I_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('measerr_scale_Z.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
x=data.iloc[:,1]
w=data.iloc[:,2]



print(stats.stdev(y)) # desviación estandar 
#print(stats.stdev(w)) # desviación estandar 
print(data)
# Out:
# 0.1534460963670065
#            A             B             C
# 0   1.128665  2.660000e+45  2.350000e+44
# 1   0.928674  3.990000e+43  1.560000e+43
# 2   1.128355  3.690000e+44  1.900000e+44
# 3   1.291580  3.470000e+45  1.280000e+43
# 4   0.993960  5.480000e+43  4.060000e+43
# ..       ...           ...           ...
# 74  1.113575  1.410000e+45  5.230000e+43
# 75  1.195405  3.380000e+44  3.120000e+43
# 76  1.072265  9.040000e+44  3.340000e+43
# 77  1.027135  1.320000e+43  5.220000e+43
# 78  1.103926  2.890000e+44  8.750000e+43
#
# [79 rows x 3 columns]

# %%
yerror = 0.1534460963670065
xerror = w
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('measerr_scale_Z')
plt.xlabel('erg/seg')
plt.title("Luminosidad_UV_GALEX_5100")
plt.xscale('log')
#plt.yscale('log')
#plt.ylim(0,)
#plt.xlim(10e44,11e45)
plt.grid()
plt.savefig("Luminosidad_UV_GALEX_measerr_scale_Z_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
